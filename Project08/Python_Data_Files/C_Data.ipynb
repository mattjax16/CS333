# %% [markdown]
# ## Projet 8 C Data

# %% [markdown]
# #### Sorthing Threads Task 1.

# %%
# Importing the nessiscary packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use(['seaborn-colorblind', 'seaborn-darkgrid'])
plt.rcParams.update({'font.size': 20})


np.set_printoptions(suppress=True, precision=5)

# Automatically reload external modules
# %load_ext autoreload
# %autoreload 2

# %%
# importing the data
df1 = pd.read_csv("/Users/matthewbass/Documents/School_Colby/Colby/CS333/Project08/Data/c_t1_stats_2022-01-25_13:08:30.csv")
df1.set_index('Size',inplace=True)
df1.drop('Unnamed: 51', axis = 1,inplace=True)
# memA_df1.columns = np.arange(len(memA_df1.columns))+1
# memA_df1
df1

# %%
df1.T.plot(figsize = (10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Clearly there is a large difference when there are 100000 (obviousy based on how I incrementedet the data by myltiplying by 10 each time).
#
# So I will drop this size and plot the new data frame

# %%
df1_2 = df1.drop(100000, axis = 0,inplace=False)
df1_2.T.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Still same consistent trend with little improvement.
